# %%
# pip install geojson
# Out:
#   Cell In[3], line 2
#     pip install lapsy
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
# pip install openpyxl --upgrade

# %%
col_df = pd.read_excel(r"C:\Users\lueva\OneDrive\Documentos\EAE\Code\Progreso\FMT-Progreso\data\raw\progreso_polygons_col.xlsx")
col_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Member card              42 non-null     object
#  1   First name               42 non-null     object
#  2   Coffee plot ID (1)       42 non-null     int64
#  3   Coffee plot name (1)     42 non-null     object
#  4   Coffee plot GeoJson (1)  42 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.8+ KB

# %%
col_df["Coffee plot GeoJson (1)"][2]
# Out:
# '{"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[-75.9844,1.92269],[-75.98414,1.92241],[-75.98363,1.92249],[-75.98336,1.92251],[-75.98329,1.92267],[-75.98309,1.923],[-75.98277,1.92385],[-75.98333,1.92409],[-75.98389,1.92385],[-75.98428,1.92347],[-75.9844,1.92269]]]},"properties":{"plot_name":"Lote","plot_id":"1915"}}]}'

# %%
col_df
# Out:
#    Member card First name  Coffee plot ID (1) Coffee plot name (1)  \
# 0      Member1    Farmer1                1701           Las Brisas
# 1      Member2    Farmer2                1703                Lotes
# 2      Member3    Farmer3                1704                 Lote
# 3      Member5    Farmer5                1734              El viso
# 4      Member7    Farmer7                1736            Salamanca
# 5      Member9    Farmer9                1738          Buena vista
# 6     Member10   Farmer10                1746         Buenos Aires
# 7     Member12   Farmer12                1748             La Aldea
# 8     Member14   Farmer14                1752            La Ladera
# 9     Member15   Farmer15                1753            Aposentos
# 10    Member16   Farmer16                1754             Larguero
# 11    Member20   Farmer20                1769             Guayamba
# 12    Member21   Farmer21                1770            Las Rocas
# ...
